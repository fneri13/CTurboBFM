# %%
import numpy as np
import pandas as pd
import pickle
import os
import matplotlib.pyplot as plt
import pandas as pd
from Utils.styles import *
from Grid.src.functions import contour_template

# %%
su2File = "su2_lowerwall.csv"
ctbfmFile = "Volume_CSV/results.csv"

# %%
su2 = pd.read_csv(su2File)

# %%
with open(ctbfmFile, 'r') as f:
    ni = int(f.readline().strip().split('=')[1])
    nj = int(f.readline().strip().split('=')[1])
    nk = int(f.readline().strip().split('=')[1])

df = pd.read_csv(ctbfmFile, skiprows=3)
ctbfm = {col: df[col].to_numpy().reshape((ni, nj, nk)) for col in df.columns}

# %%
# Create figure and axes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,4))

# Primary y-axis: Mach number (C0)
ax1.plot(su2['Points_0'], su2['Mach'], '-', mfc='none', color='C0', label='SU2')
ax1.plot(ctbfm['x'][:,0,0], ctbfm['Mach'][:,0,0], '--', mfc='none', color='C1', label='Current')
ax1.set_xlabel(r'$x$ [m]')
ax1.set_ylabel(r'$M$ [-]')
ax1.grid(alpha=0.2)

# Secondary y-axis: Pressure (C1)
# ax2 = ax1.twinx()
ax2.plot(su2['Points_0'], su2['Pressure']/1000, '-', mfc='none', color='C0')
ax2.plot(ctbfm['x'][:,0,0], ctbfm['Pressure'][:,0,0]/1000, '--', mfc='none', color='C1')    
ax2.set_ylabel(r'$p$ [kPa]')
ax2.grid(alpha=0.2)
ax2.set_xlabel(r'$x$ [m]')


# Build custom legend: only two entries (SU2 and Current)

fig.legend(loc='upper center', ncol=2, bbox_to_anchor=(0.5, 1.1))
plt.tight_layout()
# Save figure
plt.savefig("Pictures/CircularBump_Mach_Pressure.pdf", bbox_inches='tight')
# plt.show()

# %%
# plot grid
plt.figure(figsize=(8,3))
ni,nj,nk = ctbfm['x'].shape
for i in range(1, ni-1):
    plt.plot(ctbfm['x'][i, :, 0] , ctbfm['y'][i, :, 0] , 'k', lw=0.2)
for j in range(1, nj-1):
    plt.plot(ctbfm['x'][:, j, 0] , ctbfm['y'][:, j, 0] , 'k', lw=0.2)

plt.plot(ctbfm['x'][0, :, 0] , ctbfm['y'][0, :, 0] , 'C0', label='Inlet', lw=3.5)
plt.plot(ctbfm['x'][:, 0, 0] , ctbfm['y'][:, 0, 0] , 'C2', label='Inviscid Wall', lw=3.5)
plt.plot(ctbfm['x'][:, -1, 0] , ctbfm['y'][:, -1, 0] , 'C2', lw=3.5)
plt.plot(ctbfm['x'][-1, :, 0] , ctbfm['y'][-1, :, 0] , 'C1',label='Outlet', lw=3.5)

plt.plot(ctbfm['x'][ni//2, :, 0], ctbfm['y'][ni//2, :, 0], '--r', lw=2.5, label='Monitor Planes')
plt.plot(ctbfm['x'][:, 0, 0], ctbfm['y'][:, 0, 0], '--r', lw=2.5)



plt.xlabel(r'$x$ [m]')
plt.ylabel(r'$y$ [m]')
# plt.gca().set_aspect('equal', adjustable='box')

plt.legend(ncol=2, bbox_to_anchor=(0.5, 1.4), loc='upper center')
plt.savefig('Pictures/circularbump_grid.pdf', bbox_inches='tight')

# %%
su2 = pd.read_csv("su2_monitorplane.csv")

# Create figure and axes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,4))

# Primary y-axis: Mach number (C0)
ax1.plot(su2['Points_1'], su2['Mach'], '-', mfc='none', color='C0', label='SU2')
ax1.plot(ctbfm['y'][ni//2,:,0], ctbfm['Mach'][ni//2,:,0], '--', mfc='none', color='C1', label='Current')
ax1.set_xlabel(r'$y$ [m]')
ax1.set_ylabel(r'$M$ [-]')
ax1.grid(alpha=0.2)

# Secondary y-axis: Pressure (C1)
# ax2 = ax1.twinx()
ax2.plot(su2['Points_1'], su2['Pressure']/1000, '-', mfc='none', color='C0')
ax2.plot(ctbfm['y'][ni//2,:,0], ctbfm['Pressure'][ni//2,:,0]/1000, '--', mfc='none', color='C1')
ax2.set_ylabel(r'$p$ [kPa]')
ax2.set_xlabel(r'$y$ [m]')
ax2.grid(alpha=0.2)


# Build custom legend: only two entries (SU2 and Current)

fig.legend(loc='upper center', ncol=2, bbox_to_anchor=(0.5, 1.1))
plt.tight_layout()
# Save figure
plt.savefig("Pictures/CircularBump_Mach_Pressure_check2.pdf", bbox_inches='tight')
# plt.show()

# %%
ctbfm['x'][ni//2,:,0]
# Out:
# array([1.51252, 1.51251, 1.51251, 1.5125 , 1.5125 , 1.51249, 1.51249,
#        1.51248, 1.51248, 1.51247, 1.51247, 1.51246, 1.51246, 1.51245,
#        1.51245, 1.51244, 1.51244, 1.51243, 1.51242, 1.51242, 1.51242,
#        1.51241, 1.5124 , 1.5124 , 1.51239, 1.51239, 1.51238, 1.51238,
#        1.51237, 1.51237, 1.51236, 1.51236, 1.51235, 1.51235, 1.51234,
#        1.51234, 1.51233, 1.51233, 1.51232, 1.51232, 1.51231, 1.51231,
#        1.5123 , 1.5123 , 1.51229, 1.51229, 1.51228, 1.51228, 1.51227,
#        1.51227, 1.51226, 1.51226, 1.51225, 1.51225, 1.51224, 1.51224,
#        1.51223, 1.51223, 1.51222, 1.51222, 1.51221, 1.51221, 1.5122 ,
#        1.51219])
